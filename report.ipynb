# %% [markdown]
# # Datamigos - The Iron Curtain Dirty Movie Secret - Report 2024

# %% [markdown]
# - [1 - Dataset and Cleaning](#1---Dataset-and-Cleaning)

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from src.dataset_creation.cmu_merging_cleaning import *
from src.dataset_creation.datasets_merging import *
from src.dataset_creation.gpt_4o_data_enhancement import *
from src.dataset_creation.merged_dataset_preprocessing import *

from src.utils.constants import *
from src.utils.helpers import *

# %% [markdown]
# ## 1 - Dataset Merging and Cleaning

# %% [markdown]
# As described in Milestone 2, our final dataset is composed of the CMU Movie Summary Corpus extanded with two external datasets:
#
# - [The Movies Dataset (TMDb)](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset) contains metadata for 45,000 films listed in the Full MovieLens Dataset, all of which were released on or before July 2017. We will use this dataset, specifically the movies_metadata.csv file, primarily to enrich the movie.metadata.tsv of the CMU movie dataset. Additionally, this dataset includes plot keywords (in the keywords.csv file), which will be helpful for analyzing movie plots.
#
# - [IMDB Non-Commercial Dataset](https://developer.imdb.com/non-commercial-datasets/) is a giant database containing over 50 Million movies from different regions, which allows us to complement our initial dataset specifically with movies created in the Soviet Union during the cold war. The CMU Movie Summaries data being largely focused on the United States.

# %% [markdown]
# We first load, merge and clean the CMU Movie Summary Corpus dataset:

# %%
cmu_dataset = create_plot_summary_dataset()
print(cmu_dataset.shape)
cmu_dataset.sample(5)
# Out:
# (81694, 10)
#        wikipedia_id freebase_id                       title release_date  \
# 67319      16356812  /m/03whpr7  Ai Margini della Metropoli   1952-01-01
# 34900      22644734  /m/05zpb_m             Vroeger is dood   1987-01-01
# 60758      30009185  /m/09gqsm2               Den nye lægen   1943-12-26
# 21761      34084031  /m/0hr16v9           The Orphan Killer   2011-11-01
# 348         9105523  /m/027xtwf               Picture Bride   1994-05-01
#
#        revenue  runtime            languages  \
# 67319      NaN     96.0   [Italian Language]
# 34900      NaN      NaN     [Dutch Language]
# 60758      NaN     91.0                  NaN
# 21761      NaN      NaN                  NaN
# 348        NaN    100.0  [Japanese Language]
#
#                                countries  \
# 67319                            [Italy]
# 34900                      [Netherlands]
# 60758                           [Norway]
# 21761                                NaN
# 348    [United States of America, Japan]
#
#                                                   genres  \
# 67319                   [Crime Fiction, Black-and-white]
# 34900                                            [Drama]
# 60758                                            [Drama]
# 21761                                           [Horror]
# 348    [Japanese Movies, World cinema, Docudrama, Mar...
#
#                                             plot_summary
# 67319                                                NaN
# 34900                                                NaN
# 60758                                                NaN
# 21761  The film follows the life of two children who ...
# 348    The film is set in 1918. Riyo  is a "city girl...

# %% [markdown]
# We now merge TMDb and IMDb datasets with the CMU Movie Summary Corpus dataset and clean the resulting dataset.

# %%
merged_dataset = create_merged_dataset()
print(merged_dataset.shape)
merged_dataset.sample(5)
# Out:
# (25621, 10)
#         wikipedia_id freebase_id                   title  \
# 95072      9036116.0  /m/027vccd             The Cousins
# 105972     7091498.0   /m/0h3qtp  The Quick and the Dead
# 54816      6883275.0   /m/0gv4n1         Let's Make Love
# 14721     31523947.0  /m/0glspdb           Boardinghouse
# 89873            NaN         NaN    Taina zelyonogo bora
#
#                                               languages  \
# 95072                                               NaN
# 105972                                        [English]
# 54816   [English, Deutsch, العربية, Italiano, Français]
# 14721                                               NaN
# 89873                                               NaN
#
#                                 countries                      genres  \
# 95072                           [Ukraine]                     [Drama]
# 105972  [Japan, United States of America]           [Action, Western]
# 54816          [United States of America]  [Comedy, Musical, Romance]
# 14721                      [Soviet Union]            [Comedy, Horror]
# 89873                      [Soviet Union]                 [Adventure]
#
#                                                 keywords  release_date  \
# 95072                                                NaN          1959
# 105972  [gunslinger, revenge, prairie, shootout, pistol]          1975
# 54816                                          [musical]          1960
# 14721                                                NaN          1982
# 89873                                                NaN          1961
#
#         runtime                                       plot_summary
# 95072     108.0  A pair of cousins share a flat, but animosity ...
# 105972    100.0  A mysterious woman comes to compete in a quick...
# 54816     119.0  The plot revolves around billionaire Jean-Marc...
# 14721      98.0  On September 18, 1972, the Hoffman house was c...
# 89873       NaN  Three boys in a revolutionary Russia village h...

# %% [markdown]
# ## 2 - Data Enhancement with GPT-4o mini and cleaning

# %% [markdown]
# We used the GPT-4o mini model to generate 6 new columns for our dataset. The columns are:
# - `cold_war_side` - What side of the cold war the country belongs to if any
# - `character_western_bloc_representation` - How the character representing the western block is portrayed
# - `character_eastern_bloc_representation` - How the character representing the eastern block is portrayed
# - `eastern_bloc_values` - The values represented by the eastern block
# - `western_bloc_values` - The values represented by the western block
# - `theme` - The theme and keywords of the movie
#
# This will be very useful later on to grasp the context of the movies and to understand the values and themes they represent.
#
# this is the prompt we used to generate the new columns:
#
# > You are an expert in movie history and Cold War. You will be given the name of the film, the year and the plot of the movie. You first need to analyse if the movie can be identified to the Eastern or Western bloc during the Cold War. If yes come up with the character or group of character impersonating the Western and Eastern bloc and their values as well as their main archetye.
# > Your output needs to be parsable comma separated without context (the output needs to start directly), use only keyword and very important use new line character after each of the following:
# > - Cold War side belonging either Easter, Western or None.
# > - The character or group of character representing Western bloc with their values and archetype comma separated or None.
# > - The character or group of character representing Eastern bloc with their values and archetype comma separated or None.
# > - The Western bloc representation main values and characteristics comma separated or None.
# > - The Eatern bloc representation main values and characteristics comma separated or None.
# > - The theme of the movies and keywords.
# > If and only if the movie does not belong to any of the blocs, put `None` in the respective fields.
#
#
# This is the script we used to call the api and generate the new columns:

# %%
import src.prompt_engineering.prompt_engineering
output_4o = pickle.load(open(DATA_FOLDER_PREPROCESSED + 'output4o.pkl', "rb"))
output_4o[0]
# Out:
# 'Western  \nJoe Collins, American bank security consultant, resourceful, clever, hero archetype  \nDawn Divine, hooker with a heart of gold, cunning, loyal, anti-heroine archetype  \nNone  \nResourcefulness, cleverness, individualism, heroism  \nNone  \nCrime, heist, betrayal, survival, trust, money, adventure'

# %% [markdown]
# We need to parse all the output of GPT and clean it to be able to use it in our dataset.

# %%
merged_dataset_enhanced = create_enhanced_dataset()
merged_dataset_enhanced.sample(5)
# Out:
#        wikipedia_id freebase_id                  title  \
# 16825     9810279.0  /m/02psy44           Spring Fever
# 21395     9287656.0  /m/0283413  The Prisoner of Zenda
# 11762     2001394.0   /m/06d3ll          Midnight Lace
# 20001           NaN         NaN            The Hussars
# 19368    26286968.0  /m/0b73tbb               The Flaw
#
#                     languages                     countries  \
# 16825             ['English']  ['United States of America']
# 21395  ['Español', 'English']  ['United States of America']
# 11762             ['English']  ['United States of America']
# 20001                     NaN              ['Soviet Union']
# 19368             ['English']            ['United Kingdom']
#
#                                   genres  \
# 16825                         ['Comedy']
# 21395  ['Romance', 'Adventure', 'Drama']
# 11762   ['Thriller', 'Crime', 'Mystery']
# 20001                  ['Comedy', 'War']
# 19368         ['Foreign', 'Documentary']
#
#                                                 keywords  release_date  \
# 16825                                           ['golf']          1982
# 21395  ['kidnapping', 'coronation', 'villain', 'kingd...          1952
# 11762  ['london england', 'suspicion', 'threat to dea...          1960
# 20001                                                NaN          1955
# 19368  ['wall street', 'banking', 'economics', 'finan...          1955
#
#        runtime                                       plot_summary  \
# 16825    100.0  Two girls competing in a tennis match suddenly...
# 21395     96.0  An Englishman on a Ruritarian holiday must imp...
# 11762    110.0  Newlywed American heiress Kit Preston is livin...
# 20001      NaN  This satire on militarism is set during the pe...
# 19368     61.0  The story of the credit bubble that  caused th...
#
#       cold_war_side character_western_bloc_representation  \
# 16825        "None"                                [None]
# 21395        "None"                                [None]
# 11762        "None"                                [None]
# 20001        "None"                                [None]
# 19368        "None"                                [None]
#
#       character_eastern_bloc_representation western_bloc_values  \
# 16825                                [None]              [None]
# 21395                                [None]              [None]
# 11762                                [None]              [None]
# 20001                                [None]              [None]
# 19368                                [None]              [None]
#
#       eastern_bloc_values                                              theme
# 16825              [None]  [competition, friendship, spontaneity, youth, ...
# 21395              [None]      [Impersonation, monarchy, adventure, loyalty]
# 11762              [None]  [Suspense, Isolation, Trust, Betrayal, Mental ...
# 20001              [None]  [Satire, militarism, French Revolution, Napole...
# 19368              [None]  [Financial crash, credit bubble, interviews, e...

# %% [markdown]
# We now do a final cleaning, processing and drop useless columns of the dataset to prepare it for analysis.

# %%
preprocess_movies = create_preprocessed_movies()
preprocess_movies.sample(5)
# Out:
#                    title          languages                   countries  \
# 16921           Starlift  [English, French]  [United States of America]
# 4221    Cries & Whispers                NaN                 [Lithuania]
# 19995        The Hunters          [English]  [United States of America]
# 18681           The Club          [English]                    [Russia]
# 7026   Game of Seduction                NaN                    [Russia]
#
#                                genres  release_date cold_war_side  \
# 16921          [Comedy, Drama, Music]          1951     "Western"
# 4221                          [Drama]          1972        "None"
# 19995   [Action, Romance, Drama, War]          1958     "Western"
# 18681  [Comedy, Horror, Drama, Sport]          1994        "None"
# 7026                          [Drama]          1976        "None"
#
#                    character_western_bloc_representation  \
# 16921  [ friendship, love, duty, archetype: soldiers ...
# 4221                                              [None]
# 19995  [Major Cleve "Iceman" Saville, Commanding offi...
# 18681                                             [None]
# 7026                                              [None]
#
#       character_eastern_bloc_representation  \
# 16921                                [None]
# 4221                                 [None]
# 19995                                [None]
# 18681                                [None]
# 7026                                 [None]
#
#                            western_bloc_values eastern_bloc_values  \
# 16921       [Friendship, love, duty, optimism]              [None]
# 4221                                    [None]              [None]
# 19995  [Camaraderie, Bravery, Duty, Sacrifice]              [None]
# 18681                                   [None]              [None]
# 7026                                    [None]              [None]
#
#                                                    theme
# 16921  [Romantic comedy, military, love, friendship, ...
# 4221   [Family, Emotions, Death, Repression, Relation...
# 19995  [Military conflict, Heroism, Sacrifice, Friend...
# 18681  [Coming of age, self-discovery, morality, iden...
# 7026     [Seduction, Betrayal, Love, Duels, Aristocracy]

# %% [markdown]
# ## 3 - Data Exploration
