# %%
import pandas as pd
from src.utils.helpers import *
from utils.constants import *
import pickle
import glob

# %% [markdown]
# We used GPT 4o mini to compute 6 new columns for the dataset. The columns are:
#
# - `cold_war_side` - What side of the cold war the country belongs to if any
# - `character_western_bloc_representation` - How the character representing the western block is portrayed
# - `character_eastern_bloc_representation` - How the character representing the eastern block is portrayed
# - `eastern_bloc_values` - The values represented by the eastern block
# - `western_bloc_values` - The values represented by the western block
# - `theme` - The theme and keywords of the movie
#
# This will be very useful later on to grasp the context of the movies and to understand the values and themes they represent.

# %%
import prompt_engineering.prompt_engineering

# %% [markdown]
# How we queried the model for each row of the csv `merged_movies.csv` is in the python script above.
# Let's load the output and incorporate it into the dataset.

# %%
output_4o = pickle.load(open(DATA_FOLDER_PREPROCESSED + "output4o.pkl", "rb"))

parsed_4o = []

def parse_gpt_answer(answer):

    def split(line):
        line = re.sub(r"^[^:]*:", "", line)
        line = line.replace(", ", ",")
        # remove lasst character if " "
        if line[-1] == " ":
            line = line[:-1]
        return re.split(r",|\n", line)

    parsed_answer = {}
    
    answer = answer.replace(" \n", "\n")
    answer = answer.replace("\n\n", "\n")
    
    # Split the answer
    answer = answer.split("\n")
    
    
    try:
        # Parse the Cold War side
        parsed_answer["cold_war_side"] = answer[0]
        # Parse the Western bloc representation
        parsed_answer["character_western_bloc_representation"] = split(answer[1])
        # Parse the Eastern bloc representation
        parsed_answer["character_eastern_bloc_representation"] = split(answer[2])
        # Parse the Western bloc values;
        parsed_answer["western_bloc_values"] = split(answer[3])
        # Parse the Eastern bloc values
        parsed_answer["eastern_bloc_values"] = split(answer[4])
        # Parse the theme of the movie
        parsed_answer["theme"] = split(answer[5])
    except:
        parsed_answer = {"cold_war_side": 'None', 
                         "character_western_bloc_representation": 'None', 
                         "character_eastern_bloc_representation": 'None', 
                         "western_bloc_values": 'None', 
                         "eastern_bloc_values": 'None', 
                         "theme": 'None'}

    return parsed_answer

for answer in output_4o:
    parsed_4o.append(parse_gpt_answer(answer))

parsed_4o[0]
# Out:
# {'cold_war_side': 'Western ',
#  'character_western_bloc_representation': ['Joe Collins',
#   'American bank security consultant',
#   'resourceful',
#   'clever',
#   'hero archetype'],
#  'character_eastern_bloc_representation': ['Dawn Divine',
#   'hooker with a heart of gold',
#   'cunning',
#   'loyal',
#   'anti-heroine archetype'],
#  'western_bloc_values': ['None'],
#  'eastern_bloc_values': ['Resourcefulness',
#   'cleverness',
#   'individualism',
#   'heroism'],
#  'theme': ['None']}

# %%
movies_df = pd.read_csv(DATA_FOLDER_PREPROCESSED + "merged_movies.csv")
movies_df = movies_df.assign(**{key: [d[key] for d in parsed_4o] for key in parsed_4o[0].keys()})
movies_df
# Out:
#        wikipedia_id freebase_id                            title  \
# 0         4213160.0   /m/0bq8q8                                $
# 1               NaN         NaN              $1,000 on the Black
# 2               NaN         NaN              $10,000 Blood Money
# 3               NaN         NaN               $100,000 for Ringo
# 4               NaN         NaN                  'Anna' i wampir
# ...             ...         ...                              ...
# 25616           NaN         NaN                 Şaban Oğlu Şaban
# 25617    28379533.0  /m/0crc6s_          Šíleně smutná princezna
# 25618           NaN         NaN                    Убить дракона
# 25619           NaN         NaN                  ’Round Midnight
# 25620           NaN         NaN  …And the Fifth Horseman Is Fear
#
#                                 languages  \
# 0                                     NaN
# 1                 ['Italiano', 'Deutsch']
# 2                                     NaN
# 3                            ['Italiano']
# 4                                     NaN
# ...                                   ...
# 25616                          ['Türkçe']
# 25617                           ['Český']
# 25618                         ['Pусский']
# 25619  ['English', 'Français', 'Deutsch']
# 25620                           ['Český']
#
#                                     countries                         genres  \
# 0                            ['Soviet Union']   ['Comedy', 'Crime', 'Drama']
# 1                        ['Italy', 'Germany']                    ['Western']
# 2                            ['Soviet Union']           ['Western', 'Drama']
# 3                                   ['Italy']           ['Western', 'Drama']
# 4                            ['Soviet Union']                      ['Crime']
# ...                                       ...                            ...
# 25616                              ['Turkey']                     ['Comedy']
# 25617                      ['Czech Republic']  ['Comedy', 'Music', 'Family']
# 25618                   ['Russia', 'Germany']           ['Drama', 'Fantasy']
# 25619  ['France', 'United States of America']                      ['Drama']
# 25620                      ['Czech Republic']               ['War', 'Drama']
#
#                                                 keywords  release_date  \
# 0                                                    NaN          1971
# 1                                                    NaN          1966
# 2                                                    NaN          1967
# 3                      ['spaghetti western', 'whipping']          1965
# 4                                                    NaN          1982
# ...                                                  ...           ...
# 25616                                                NaN          1977
# 25617  ['fairy tale', 'wedding', 'aristocrat', 'pohád...          1968
# 25618                                                NaN          1988
# 25619                   ['jazz', 'musical', 'biography']          1986
# 25620                                                NaN          1965
#
#        runtime                                       plot_summary  \
# 0        119.0  Set in Hamburg, West Germany, several criminal...
# 1        104.0  Johnny Liston has just been released from pris...
# 2          NaN  Hired by a Mexican landowner to rescue his dau...
# 3         98.0  A stranger rides into Rainbow Valley where he'...
# 4          NaN  Silesia in Poland, late 60s. Bodies of vicious...
# ...        ...                                                ...
# 25616     90.0                                 No overview found.
# 25617     86.0                                 No overview found.
# 25618    123.0  Dragon is a bloody dictator, who kills every o...
# 25619    133.0  Inside the Blue Note nightclub one night in 19...
# 25620    100.0  A Jewish doctor helps a political fugitive dur...
#
#       cold_war_side              character_western_bloc_representation  \
# 0          Western   [Joe Collins, American bank security consultan...
# 1           Eastern                                             [None]
# 2             None                                              [None]
# 3             None                                              [None]
# 4          Eastern                                              [None]
# ...             ...                                                ...
# 25616         None                                              [None]
# 25617         None                                              [None]
# 25618      Eastern                                              [None]
# 25619         None                                              [None]
# 25620         None                                              [None]
#
#                    character_eastern_bloc_representation  \
# 0      [Dawn Divine, hooker with a heart of gold, cun...
# 1      [Sartana, villainous, oppressive, cruel, arche...
# 2                                                 [None]
# 3                                                 [None]
# 4                                                 [None]
# ...                                                  ...
# 25616                                             [None]
# 25617                                             [None]
# 25618     [Lancelot, heroism, freedom, knight archetype]
# 25619                                             [None]
# 25620                                             [None]
#
#                                      western_bloc_values  \
# 0                                                 [None]
# 1      [Johnny Liston, justice, determination, resili...
# 2                                                 [None]
# 3                                                 [None]
# 4                                                 [None]
# ...                                                  ...
# 25616                                             [None]
# 25617                                             [None]
# 25618                                             [None]
# 25619                                             [None]
# 25620                                             [None]
#
#                                      eastern_bloc_values  \
# 0      [Resourcefulness, cleverness, individualism, h...
# 1      [Justice, revenge, oppressed vs. oppressor, re...
# 2                                                 [None]
# 3                                                 [None]
# 4                                                 [None]
# ...                                                  ...
# 25616                                             [None]
# 25617                                             [None]
# 25618  [Fear, oppression, totalitarianism, resistance...
# 25619                                             [None]
# 25620                                             [None]
#
#                                                    theme
# 0                                                 [None]
# 1      [Terror, betrayal, familial conflict, crime, r...
# 2      [crime, betrayal, revenge, bounty hunter, heis...
# 3      [Western, Civil War, mistaken identity, treasu...
# 4           [murder mystery, horror, fog, Poland, 1960s]
# ...                                                  ...
# 25616                                            [None ]
# 25617                                            [None ]
# 25618  [Themes of rebellion, freedom vs. oppression, ...
# 25619       [Jazz, Friendship, Paris, Music, Creativity]
# 25620  [Nazi occupation, Czechoslovakia, Jewish ident...
#
# [25621 rows x 16 columns]

# %%
import re

global count

count = 0

def preprocess_side(row):
    # remove all non alphanumeric characters
    try:
        row['cold_war_side'] = re.sub(r'\W+', '', row['cold_war_side'])
    except:
        row['cold_war_side'] = "None"
    
    if row["character_western_bloc_representation"] is np.nan:
        row["character_western_bloc_representation"] = ['None']
    if row["character_eastern_bloc_representation"] is np.nan:
        row["character_eastern_bloc_representation"] = ['None']
    if row["western_bloc_values"] is np.nan:
        row["western_bloc_values"] = ['None']
    if row["eastern_bloc_values"] is np.nan:
        row["eastern_bloc_values"] = ['None']
    if row["theme"] is np.nan:
        row["theme"] = ['None']
        
    # print(row["western_bloc_values"][0])
    
    if (row["character_western_bloc_representation"][0] == "None" and row["character_eastern_bloc_representation"][0] == "None") and row['cold_war_side'] != "None":
    # if (row["western_bloc_values"][0] == "None" and row["eastern_bloc_values"][0] == "None") and row['cold_war_side'] != "None":
        # print(row)
        # print("-----------------")
        global count
        count += 1
        row['cold_war_side'] = "None"
    
    return row

# %%
movies_df2 = movies_df.apply(preprocess_side, axis=1)
movies_df2["cold_war_side"] = movies_df2["cold_war_side"].apply(lambda x: f'"{x}"')

# %%
movies_df2.value_counts("cold_war_side")
# Out:
# cold_war_side
# "None"       19560
# "Western"     3142
# "Eastern"     2919
# Name: count, dtype: int64

# %%
# save data in a csv
movies_df2.to_csv(DATA_FOLDER_PREPROCESSED + "v2_movies_cleaned.csv", index=False)
