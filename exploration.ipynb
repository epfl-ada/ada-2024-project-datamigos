# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies_df = pd.read_csv("data/preprocessed/v1_movies.csv")
movies_df.head()
# Out:
#    wikipedia_id freebase_id                title                languages  \
# 0     4213160.0   /m/0bq8q8                    $              ['English']
# 1           NaN         NaN  $1,000 on the Black  ['Deutsch', 'Italiano']
# 2           NaN         NaN  $10,000 Blood Money                      NaN
# 3           NaN         NaN   $100,000 for Ringo             ['Italiano']
# 4     2250713.0   /m/06z7m4                  '68              ['English']
#
#                                  countries  \
# 0             ['United States of America']
# 1                     ['Italy', 'Germany']
# 2                         ['Soviet Union']
# 3                                ['Italy']
# 4  ['United States of America', 'Hungary']
#
#                                               genres  \
# 0  ['Drama', 'Comedy', 'Action', 'Thriller', 'Hei...
# 1                                        ['Western']
# 2                               ['Drama', 'Western']
# 3                               ['Drama', 'Western']
# 4  ['Drama', 'Coming of age', 'Family Drama', 'Pe...
#
#                             keywords release_date  runtime  \
# 0                                NaN   1971-12-17    119.0
# 1                                NaN   1966-12-18    104.0
# 2                                NaN   1967-01-01      NaN
# 3  ['spaghetti western', 'whipping']   1965-11-18     98.0
# 4                                NaN   1988-01-01     98.0
#
#                                         plot_summary  year_release_date  \
# 0  Set in Hamburg, West Germany, several criminal...               1971
# 1  Johnny Liston has just been released from pris...               1966
# 2  Hired by a Mexican landowner to rescue his dau...               1967
# 3  A stranger rides into Rainbow Valley where he'...               1965
# 4  The father escaped the Soviet invasion of Buda...               1988
#
#   cold_war_side              character_western_bloc_representation  \
# 0      Western   ['Joe Collins', 'American bank security consul...
# 1      Western   ['Johnny Liston', 'justice', 'redemption', 'he...
# 2         None                                            ['None']
# 3         None                                            ['None']
# 4         None                                            ['None']
#
#                character_eastern_bloc_representation  \
# 0  ['Sarge', 'corrupt U.S. Army sergeant', 'value...
# 1   ['Sartana', 'tyranny', 'betrayal', 'antagonist']
# 2                                           ['None']
# 3                                           ['None']
# 4                                           ['None']
#
#                                  western_bloc_values  \
# 0  ['Cunning', 'heroism', 'cleverness', 'survival...
# 1  ['Justice', 'redemption', 'individualism', 'pe...
# 2                                           ['None']
# 3                                           ['None']
# 4                                           ['None']
#
#                                  eastern_bloc values  \
# 0  ['Ruthlessness', 'violence', 'greed', 'betraya...
# 1      ['Tyranny', 'fear', 'betrayal', 'oppression']
# 2                                           ['None']
# 3                                           ['None']
# 4                                           ['None']
#
#                                                theme
# 0  ['Heist', 'crime', 'betrayal', 'survival', 'te...
# 1  ['Revenge', 'self-discovery', 'moral conflict'...
# 2    ['Betrayal', 'Greed', 'Bounty Hunter', 'Heist']
# 3  ['Western', 'Frontier', 'Stranger', 'Rivalry',...
# 4  ['Gay rights', 'counterculture', 'family confl...

# %%
movies_df["cold_war_side"].value_counts()
# Out:
# cold_war_side
# None         22787
# Western       3585
# Eastern       3404
# Western        327
# Eastern         49
# None,           44
# None             6
# Western,         2
# Name: count, dtype: int64

# %%
james_bond_movies = ["Dr. No", "From Russia with Love", "Goldfinger", "Thunderball", "You Only Live Twice", "On Her Majesty's Secret Service", "Diamonds Are Forever", "Live and Let Die", \
                     "The Man with the Golden Gun", "The Spy Who Loved Me", "Moonraker", "For Your Eyes Only", "Octopussy", "A View to a Kill", "The Living Daylights", "Licence to Kill", \
                     "GoldenEye", "Tomorrow Never Dies", "The World Is Not Enough", "Die Another Day", "Casino Royale", "Quantum of Solace", "Skyfall", "Spectre", "No Time to Die"]

james_bond_movies_df = movies_df[movies_df['title'].isin(james_bond_movies)]

james_bond_movies_df
# Out:
#        wikipedia_id freebase_id                            title  \
# 870        583932.0   /m/02sg5v                 A View to a Kill
# 4419      2461592.0  /m/01lbcqx                    Casino Royale
# 4420      9019882.0  /m/027tqgs                    Casino Royale
# 6515       157481.0  /m/01kf4tt             Diamonds Are Forever
# 7015      6446053.0  /m/025twgf                           Dr. No
# 8607      6446044.0   /m/0g5pv3               For Your Eyes Only
# 8887      6446071.0  /m/025twgt            From Russia with Love
# 9469      6322029.0  /m/01kf5lf                       Goldfinger
# 13749      449547.0   /m/029v40                  Licence to Kill
# 13940     6446061.0   /m/0g5pvv                 Live and Let Die
# 15622     6446062.0  /m/01kf3_9                        Moonraker
# 17051      541642.0   /m/02n72k                        Octopussy
# 17194     6268880.0   /m/0fztbq  On Her Majesty's Secret Service
# 21774     3015828.0   /m/08kqhx                          Spectre
# 26246      566713.0   /m/02qrv7             The Living Daylights
# 26528     6223567.0   /m/0fxmbn      The Man with the Golden Gun
# 28077     6446036.0   /m/0g5ptf             The Spy Who Loved Me
# 29380     6152265.0   /m/0fsw_7                      Thunderball
# 32044     5078515.0   /m/0d1qmz              You Only Live Twice
#
#                                                languages  \
# 870                                          ['English']
# 4419       ['', 'English', '日本語', 'Deutsch', 'Français']
# 4420       ['', 'English', '日本語', 'Deutsch', 'Français']
# 6515                    ['German', 'English', 'Deutsch']
# 7015                   ['English', 'French', 'Français']
# 8607   ['English', 'Italiano', 'Greek', 'Italian', 'ε...
# 8887   ['Romani language', 'English', 'Türkçe', 'Pусс...
# 9469   ['English', 'Spanish', 'Chinese language', 'Es...
# 13749                  ['English', 'Spanish', 'Español']
# 13940        ['English', 'Hungarian language', 'Magyar']
# 15622                 ['English', 'Italian', 'Italiano']
# 17051  ['English', 'Pусский', 'Russian', 'Spanish', '...
# 17194                   ['German', 'English', 'Deutsch']
# 21774  ['English', 'Español', 'Italiano', 'Deutsch', ...
# 26246  ['English', 'Pусский', 'Russian', 'Arabic', 'G...
# 26528  ['English', 'Cantonese', 'Chinese language', '...
# 28077  ['English', 'Italiano', 'العربية', 'Arabic', '...
# 29380                  ['English', 'French', 'Français']
# 32044  ['English', '日本語', 'Pусский', 'Russian', 'Japa...
#
#                                                countries  \
# 870    ['France', 'United Kingdom', 'Iceland', 'Unite...
# 4419      ['United Kingdom', 'United States of America']
# 4420      ['United Kingdom', 'United States of America']
# 6515      ['United Kingdom', 'United States of America']
# 7015                                  ['United Kingdom']
# 8607      ['United Kingdom', 'United States of America']
# 8887                                  ['United Kingdom']
# 9469      ['United Kingdom', 'United States of America']
# 13749     ['United Kingdom', 'United States of America']
# 13940                                 ['United Kingdom']
# 15622  ['France', 'United Kingdom', 'United States of...
# 17051     ['United Kingdom', 'United States of America']
# 17194     ['United Kingdom', 'United States of America']
# 21774     ['United Kingdom', 'United States of America']
# 26246     ['United Kingdom', 'United States of America']
# 26528  ['United Kingdom', 'Kingdom of Great Britain',...
# 28077     ['United Kingdom', 'United States of America']
# 29380  ['France', 'Thailand', 'United Kingdom', 'Baha...
# 32044                                 ['United Kingdom']
#
#                                                   genres  \
# 870    ['Glamorized Spy Film', 'Spy', 'Action Thrille...
# 4419   ['Spy', 'Parody', 'Satire', 'Comedy', 'Action'...
# 4420   ['Spy', 'Film adaptation', 'Drama', 'Comedy', ...
# 6515   ['Glamorized Spy Film', 'Spy', 'Thriller', 'Ac...
# 7015   ['Glamorized Spy Film', 'Thriller', 'Action', ...
# 8607   ['Glamorized Spy Film', 'Thriller', 'Action', ...
# 8887   ['Glamorized Spy Film', 'Thriller', 'Action', ...
# 9469   ['Glamorized Spy Film', 'Thriller', 'Action', ...
# 13749  ['Glamorized Spy Film', 'Action Thrillers', 'T...
# 13940  ['Glamorized Spy Film', 'Action Thrillers', 'B...
# 15622  ['Glamorized Spy Film', 'Sci-Fi', 'Action', 'T...
# 17051  ['Glamorized Spy Film', 'Action Thrillers', 'T...
# 17194  ['Glamorized Spy Film', 'Thriller', 'Action', ...
# 21774  ['Action', 'Television movie', 'Horror', 'Crim...
# 26246  ['Glamorized Spy Film', 'Spy', 'Action Thrille...
# 26528  ['Glamorized Spy Film', 'Action Thrillers', 'T...
# 28077  ['Glamorized Spy Film', 'Spy', 'Action Thrille...
# 29380  ['Glamorized Spy Film', 'Spy', 'Action Thrille...
# 32044  ['Glamorized Spy Film', 'Thriller', 'Action', ...
#
#                                                 keywords release_date  \
# 870    ['paris', 'london england', 'france', 'england...   1985-05-22
# 4419   ['scotland', 'casino', 'queen', 'intelligence'...   1967-01-01
# 4420   ['scotland', 'casino', 'queen', 'intelligence'...   1954-01-01
# 6515   ['spy', 'fight', 'secret organization', 'satel...   1971-12-14
# 7015   ['london england', 'england', 'assassination',...   1962-10-05
# 8607   ['london england', 'submarine', 'england', 'se...   1981-06-24
# 8887   ['venice', 'london england', 'terror', 'englan...   1963-10-11
# 9469   ['secret organization', 'secret intelligence s...   1964-09-17
# 13749  ['corruption', 'florida', 'secret identity', '...   1989-06-13
# 13940  ['london england', 'new york', 'bomb', 'englan...   1973-06-27
# 15622  ['venice', 'mass murder', 'space marine', 'spa...   1979-06-26
# 17051  ['atomic bomb', 'eastern block', 'crocodile', ...   1983-06-06
# 17194  ['london england', 'suicide', 'england', 'swit...   1969-01-01
# 21774  ['spy', 'based on novel', 'secret agent', 'seq...   1977-01-01
# 26246  ['london england', 'smuggling of arms', 'priso...   1987-01-01
# 26528  ['london england', 'england', 'martial arts', ...   1974-12-19
# 28077  ['london england', 'submarine', 'england', 'as...   1977-07-07
# 29380  ['paris', 'florida', 'fighter pilot', 'sanator...   1965-12-09
# 32044  ['london england', 'japan', 'england', 'assass...   1967-06-12
#
#        runtime                                       plot_summary  \
# 870      131.0  James Bond is sent to Siberia to locate the bo...
# 4419     130.0   The story of Casino Royale is told in an epis...
# 4420      50.0  Act I "Combined Intelligence" agent James Bond...
# 6515     115.0  James Bond – agent 007 – pursues Ernst Stavro ...
# 7015     109.0  John Strangways, the British Intelligence  Sta...
# 8607     127.0  MI6 agent James Bond, code name '007' and some...
# 8887     111.0  SPECTRE's expert planner Kronsteen devises a p...
# 9469     111.0  After destroying a drug laboratory in Latin Am...
# 13749    133.0  DEA agents collect James Bond – MI6 agent 007 ...
# 13940    121.0  Three British  agents, including one "on loan"...
# 15622    126.0  A Drax Industries Moonraker space shuttle on l...
# 17051    131.0  British agent 009 is found dead at the British...
# 17194    140.0  In Portugal, James Bond – agent 007 and someti...
# 21774     98.0  William Sebastian  is a former criminologist w...
# 26246    130.0   James Bond—agent 007—is assigned to aid the d...
# 26528    125.0  In London, a golden bullet with James Bond's c...
# 28077    126.0  British and Soviet ballistic-missile submarine...
# 29380    130.0  James Bond—MI6 agent 007 and sometimes simply ...
# 32044    117.0  An American spacecraft is hijacked from orbit ...
#
#        year_release_date cold_war_side  \
# 870                 1985      Western
# 4419                1967      Western
# 4420                1954      Western
# 6515                1971      Western
# 7015                1962      Western
# 8607                1981      Western
# 8887                1963      Western
# 9469                1964      Western
# 13749               1989      Western
# 13940               1973      Western
# 15622               1979      Western
# 17051               1983      Western
# 17194               1969      Western
# 21774               1977         None
# 26246               1987      Western
# 26528               1974      Western
# 28077               1977      Western
# 29380               1965      Western
# 32044               1967      Western
#
#                    character_western_bloc_representation  \
# 870    [' heroism', 'individualism', 'courage', 'arch...
# 4419   [' Heroism', 'Charm', 'Intelligence', 'archety...
# 4420                                           [' Hero']
# 6515   [' heroism', 'resourcefulness', 'confidence', ...
# 7015   ['James Bond', 'British agent', 'bravery', 'in...
# 8607   ['James Bond', 'British intelligence', 'braver...
# 8887   [' heroism', 'wit', 'intelligence', 'archetype...
# 9469   [' heroism', 'intelligence', 'charm', 'archety...
# 13749  [' loyalty', 'justice', 'heroism', 'archetype:...
# 13940  ['James Bond', 'loyalty', 'courage', 'hero arc...
# 15622  ['James Bond', 'MI6 operative', 'heroism', 'in...
# 17051  ['James Bond', 'courage', 'resourcefulness', '...
# 17194  [' bravery', 'charm', 'resourcefulness', 'arch...
# 21774                                           ['None']
# 26246  [' heroism', 'duty', 'individualism', 'archety...
# 26528  ['James Bond', 'British intelligence', 'herois...
# 28077  ['James Bond', 'British intelligence', 'heroic...
# 29380  [' bravery', 'loyalty', 'charm', 'archetype: h...
# 32044  ['James Bond', 'heroism', 'loyalty', 'cleverne...
#
#                    character_eastern_bloc_representation  \
# 870    [' loyalty', 'discipline', 'state control', 'a...
# 4419   [' Independence', 'Deception', 'archetype: The...
# 4420                                        [' Villain']
# 6515   [' loyalty', 'teamwork', 'expertise', 'archety...
# 7015   ['Dr. No', 'villain', 'ambition', 'ruthlessnes...
# 8607   ['General Gogol', 'Soviet intelligence', 'cunn...
# 8887   [' loyalty', 'innocence', 'archetype: the unwi...
# 9469                                            ['None']
# 13749  [' duty', 'friendship', 'resilience', 'archety...
# 13940  ['Dr. Kananga', 'manipulation', 'authoritarian...
# 15622  ['Hugo Drax', 'villain', 'elitism', 'superiori...
# 17051  ['Orlov', 'authoritarianism', 'expansionism', ...
# 17194  [' manipulation', 'control', 'ambition', 'arch...
# 21774                                           ['None']
# 26246  [' betrayal', 'deceit', 'survival', 'archetype...
# 26528  ['Francisco Scaramanga', 'anti-hero', 'greed',...
# 28077  ['Major Anya Amasova', 'KGB', 'resourceful', '...
# 29380  [' greed', 'manipulation', 'deception', 'arche...
# 32044  ['Aki', 'collaboration', 'deception', 'resourc...
#
#                                      western_bloc_values  \
# 870    [' innovation', 'technology', 'cleverness', 'a...
# 4419                                            ['None']
# 4420   ['Bravery', 'resourcefulness', 'espionage', 'l...
# 6515   [' power', 'manipulation', 'greed', 'archetype...
# 7015   ['Courage', 'loyalty', 'technology', 'justice'...
# 8607   ['Bravery', 'resourcefulness', 'heroism', 'fre...
# 8887   [' cunning', 'manipulation', 'archetype: the a...
# 9469   ['Heroism', 'intelligence', 'charm', 'adventur...
# 13749  [' greed', 'power', 'ruthlessness', 'archetype...
# 13940  ['Bravery', 'individualism', 'justice', 'moral...
# 15622  ['Courage', 'self-reliance', 'justice', 'teamw...
# 17051  ['Courage', 'resourcefulness', 'heroism', 'ind...
# 17194  ['individualism', 'freedom', 'heroism', 'roman...
# 21774                                           ['None']
# 26246  ['heroism', 'individualism', 'duty', 'justice'...
# 26528  ['Heroism', 'freedom', 'advanced technology', ...
# 28077  ['Resourcefulness', 'charm', 'heroism', 'loyal...
# 29380    ['bravery', 'loyalty', 'charm', 'intelligence']
# 32044  ['Courage', 'ingenuity', 'patriotism', 'indivi...
#
#                                      eastern_bloc values  \
# 870                                             ['None']
# 4419                                            ['None']
# 4420   ['Cunning', 'manipulation', 'conflict', 'danger']
# 6515                                            ['None']
# 7015   ['Totalitarianism', 'secrecy', 'manipulation',...
# 8607   ['Cunning', 'secrecy', 'control', 'authority',...
# 8887   [' bravery', 'resourcefulness', 'loyalty to hi...
# 9469                                            ['None']
# 13749  [' justice', 'loyalty', 'perseverance', 'coura...
# 13940  ['Despotism', 'drug trafficking', 'fear', 'con...
# 15622  ['Totalitarianism', 'superiority', 'manipulati...
# 17051  ['Authoritarianism', 'expansionism', 'deceit',...
# 17194  ['authoritarianism', 'collectivism', 'dominati...
# 21774                                           ['None']
# 26246  ['betrayal', 'deceit', 'loyalty to state', 'op...
# 26528    ['Greed', 'power', 'isolation', 'manipulation']
# 28077  ['Mission-driven', 'vengefulness', 'loyalty to...
# 29380               ['greed', 'manipulation', 'control']
# 32044  ['Surveillance', 'subterfuge', 'paranoia', 'co...
#
#                                                    theme
# 870                                          ['Eastern']
# 4419   ['Humor', 'Espionage', 'Betrayal', 'Chaos', 'A...
# 4420   ['Espionage', 'loyalty', 'betrayal', 'survival...
# 6515   ['Totalitarianism', 'espionage', 'gambling', '...
# 7015   ['Spy', 'espionage', 'good vs evil', 'technolo...
# 8607   ['Espionage', 'betrayal', 'romance', 'internat...
# 8887   [' deception', 'cold-heartedness', 'betrayal',...
# 9469   ['Espionage', 'deception', 'international intr...
# 13749  [' power', 'wealth', 'manipulation', 'brutality']
# 13940  ['Adventure', 'espionage', 'betrayal', 'herois...
# 15622  ['Action', 'espionage', 'space', 'heroism', 'g...
# 17051  ['Espionage', 'deception', 'Cold War tensions'...
# 17194  ['love', 'betrayal', 'duty', 'espionage', 'sac...
# 21774  ['Occult', 'supernaturals', 'investigation', '...
# 26246  ['Cold War', 'espionage', 'loyalty', 'betrayal...
# 26528  ['Conflict between good and evil', 'espionage'...
# 28077  ['Espionage', 'nuclear threat', 'cooperation a...
# 29380  ['espionage', 'loyalty', 'power struggle', 'in...
# 32044  ['Espionage', 'adventure', 'space race', 'Cold...
